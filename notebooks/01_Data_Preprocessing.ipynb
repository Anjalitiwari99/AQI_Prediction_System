# %% [markdown]
# # AQI Prediction System
# ## Data Preprocessing & Exploratory Data Analysis(EDA)
# Author: Anjali Tiwari

# %%
import pandas as pd
print("Pandas imported successfully")
# Out:
# Pandas imported successfully

# %% [markdown]
# ## Loading Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries loaded successfully ✅")
# Out:
# Libraries loaded successfully ✅

# %% [markdown]
# ## Reading PDF Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
import pdfplumber

pdf_path = "data/prayagraj_air_quality_data (1).pdf"

with pdfplumber.open(pdf_path) as pdf:
    print("Total Pages:", len(pdf.pages))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 5
#       1 import pdfplumber
#       2
#       3 pdf_path = "data/prayagraj_air_quality_data (1).pdf"
#       4
# ----> 5 with pdfplumber.open(pdf_path) as pdf:
#       6     print("Total Pages:", len(pdf.pages))
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pdfplumber\pdf.py:98, in PDF.open(cls, path_or_fp, pages, laparams, password, strict_metadata, unicode_norm, repair, gs_path, repair_setting, raise_unicode_errors)
#      96     path = None
#      97 elif isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 98     stream = open(path_or_fp, "rb")
#      99     stream_is_external = False
#     100     path = pathlib.Path(path_or_fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/prayagraj_air_quality_data (1).pdf'

# %%
import sys

print(sys.executable)
print(sys.version)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\python.exe
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
import pdfplumber

print("pdfplumber imported successfully ✅")
# Out:
# pdfplumber imported successfully ✅

# %% [markdown]
# ## Extracting Tables from PDF

# %%
import pdfplumber

pdf_path = "data/prayagraj_air_quality_data (1).pdf"

all_tables = []

with pdfplumber.open(pdf_path) as pdf:
    print(f"Total Pages: {len(pdf.pages)}")

    for page_num, page in enumerate(pdf.pages):

        table = page.extract_table()

        if table:
            all_tables.append(table)
            print(f"Page {page_num+1}: Table Found ✅")

        else:
            print(f"Page {page_num+1}: No Table ❌")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 7
#       3 pdf_path = "data/prayagraj_air_quality_data (1).pdf"
#       4
#       5 all_tables = []
#       6
# ----> 7 with pdfplumber.open(pdf_path) as pdf:
#       8     print(f"Total Pages: {len(pdf.pages)}")
#       9
#      10     for page_num, page in enumerate(pdf.pages):
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pdfplumber\pdf.py:98, in PDF.open(cls, path_or_fp, pages, laparams, password, strict_metadata, unicode_norm, repair, gs_path, repair_setting, raise_unicode_errors)
#      96     path = None
#      97 elif isinstance(path_or_fp, (str, pathlib.Path)):
# ---> 98     stream = open(path_or_fp, "rb")
#      99     stream_is_external = False
#     100     path = pathlib.Path(path_or_fp)
#
# ...

# %%
import os

print(os.getcwd())
# Out:
# e:\OneDrive\Desktop\AQI_Prediction_System\notebooks

# %%
import pdfplumber

pdf_path = "../data/prayagraj_air_quality_data (1).pdf"

all_tables = []

with pdfplumber.open(pdf_path) as pdf:
    print(f"Total Pages: {len(pdf.pages)}")

    for page_num, page in enumerate(pdf.pages):
        table = page.extract_table()

        if table:
            all_tables.append(table)
            print(f"Page {page_num+1}: Table Found ✅")
        else:
            print(f"Page {page_num+1}: No Table ❌")
# Out:
# Total Pages: 6
# Page 1: No Table ❌
# Page 2: No Table ❌
# Page 3: Table Found ✅
# Page 4: Table Found ✅
# Page 5: Table Found ✅
# Page 6: Table Found ✅

# %% [markdown]
# ## Preview Extracted Tables

# %%
print("Total Tables Extracted:", len(all_tables))

print("\nFirst Table Preview:\n")

for row in all_tables[0][:10]:
    print(row)
# Out:
# Total Tables Extracted: 4
#
# First Table Preview:
#
# ['OCTOBER (2015) - DECEMBER (2015)', None, None, None, None, None, None, None]
# ['', '', None, '', None, '', None, '']
# ['Air Quality Data', 'Traffic Area', None, 'Industrial Area', None, 'Residential Area', None, 'Green Area']
# [None, 'Civil Lines', 'Rambagh', 'Naini', 'Phoolpur', 'Katra', 'Teliyarganj', 'Company Bagh']
# ['AQI', '228.3', '235.0', '250.0', '260.0', '215.0', '190.0', '120.0']
# ['PM2.5 (µg/m³)', '125', '130', '140', '145', '118', '105', '60']
# ['PM10 (µg/m³)', '245', '255', '270', '280', '230', '205', '125']
# ['NO2 (µg/m³)', '34.7', '36.0', '39.0', '40.0', '32.0', '28.0', '15.0']
# ['SO2 (µg/m³)', '9.0', '9.0', '10.0', '11.0', '8.0', '7.0', '5.0']
# ['NH3 (µg/m³)', '31.3', '32.0', '34.0', '36.0', '29.0', '25.0', '15.0']

# %% [markdown]
# ## Converting Extracted Table into DataFrame

# %%
# Convert first extracted table into DataFrame

df = pd.DataFrame(all_tables[0])

print("Shape of DataFrame:", df.shape)

df.head(10)
# Out:
# Shape of DataFrame: (14, 8)
#                                   0             1        2                3  \
# 0  OCTOBER (2015) - DECEMBER (2015)           NaN      NaN              NaN
# 1                                                      NaN
# 2                  Air Quality Data  Traffic Area      NaN  Industrial Area
# 3                               NaN   Civil Lines  Rambagh            Naini
# 4                               AQI         228.3    235.0            250.0
# 5                     PM2.5 (µg/m³)           125      130              140
# 6                      PM10 (µg/m³)           245      255              270
# 7                       NO2 (µg/m³)          34.7     36.0             39.0
# 8                       SO2 (µg/m³)           9.0      9.0             10.0
# 9                       NH3 (µg/m³)          31.3     32.0             34.0
#
#           4                 5            6             7
# 0       NaN               NaN          NaN           NaN
# ...

# %% [markdown]
# ## Inspecting Extracted Data

# %%
print("Shape :", df.shape)

print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Shape : (14, 8)
#
# Columns:
# RangeIndex(start=0, stop=8, step=1)
#
# Data Types:
# 0    str
# 1    str
# 2    str
# 3    str
# 4    str
# 5    str
# 6    str
# 7    str
# dtype: object
#
# Missing Values:
# 0    1
# 1    1
# 2    3
# 3    1
# 4    3
# 5    1
# 6    3
# 7    1
# dtype: int64

# %% [markdown]
# ## Viewing Complete Extracted Table

# %%
df
# Out:
#                                    0             1        2                3  \
# 0   OCTOBER (2015) - DECEMBER (2015)           NaN      NaN              NaN
# 1                                                       NaN
# 2                   Air Quality Data  Traffic Area      NaN  Industrial Area
# 3                                NaN   Civil Lines  Rambagh            Naini
# 4                                AQI         228.3    235.0            250.0
# 5                      PM2.5 (µg/m³)           125      130              140
# 6                       PM10 (µg/m³)           245      255              270
# 7                        NO2 (µg/m³)          34.7     36.0             39.0
# 8                        SO2 (µg/m³)           9.0      9.0             10.0
# 9                        NH3 (µg/m³)          31.3     32.0             34.0
# 10                        O3 (µg/m³)          18.7     18.0             17.0
# ...

# %% [markdown]
# ## Inspecting Header Row

# %%
df.iloc[3]
# Out:
# 0             NaN
# 1     Civil Lines
# 2         Rambagh
# 3           Naini
# 4        Phoolpur
# 5           Katra
# 6     Teliyarganj
# 7    Company Bagh
# Name: 3, dtype: str

# %% [markdown]
# ## Setting Proper Column Names

# %%
df.columns = [
    "Parameter",
    "Civil Lines",
    "Rambagh",
    "Naini",
    "Phoolpur",
    "Katra",
    "Teliyarganj",
    "Company Bagh"
]

print("Column names updated successfully ✅")
# Out:
# Column names updated successfully ✅

# %%
df.head()
# Out:
#                           Parameter   Civil Lines  Rambagh            Naini  \
# 0  OCTOBER (2015) - DECEMBER (2015)           NaN      NaN              NaN
# 1                                                      NaN
# 2                  Air Quality Data  Traffic Area      NaN  Industrial Area
# 3                               NaN   Civil Lines  Rambagh            Naini
# 4                               AQI         228.3    235.0            250.0
#
#    Phoolpur             Katra  Teliyarganj  Company Bagh
# 0       NaN               NaN          NaN           NaN
# 1       NaN                            NaN
# 2       NaN  Residential Area          NaN    Green Area
# 3  Phoolpur             Katra  Teliyarganj  Company Bagh
# 4     260.0             215.0        190.0         120.0

# %% [markdown]
# ## Removing Unnecessary Header Rows

# %%
# Keep only actual air quality measurements
df_clean = df.iloc[4:].reset_index(drop=True)

print("Cleaned Shape:", df_clean.shape)

df_clean.head()
# Out:
# Cleaned Shape: (10, 8)
#        Parameter Civil Lines Rambagh  Naini Phoolpur  Katra Teliyarganj  \
# 0            AQI       228.3   235.0  250.0    260.0  215.0       190.0
# 1  PM2.5 (µg/m³)         125     130    140      145    118         105
# 2   PM10 (µg/m³)         245     255    270      280    230         205
# 3    NO2 (µg/m³)        34.7    36.0   39.0     40.0   32.0        28.0
# 4    SO2 (µg/m³)         9.0     9.0   10.0     11.0    8.0         7.0
#
#   Company Bagh
# 0        120.0
# 1           60
# 2          125
# 3         15.0
# 4          5.0

# %% [markdown]
# ## Transposing Dataset

# %%
df_final = df_clean.set_index("Parameter").T

df_final
# Out:
# Parameter       AQI PM2.5 (µg/m³) PM10 (µg/m³) NO2 (µg/m³) SO2 (µg/m³)  \
# Civil Lines   228.3           125          245        34.7         9.0
# Rambagh       235.0           130          255        36.0         9.0
# Naini         250.0           140          270        39.0        10.0
# Phoolpur      260.0           145          280        40.0        11.0
# Katra         215.0           118          230        32.0         8.0
# Teliyarganj   190.0           105          205        28.0         7.0
# Company Bagh  120.0            60          125        15.0         5.0
#
# Parameter    NH3 (µg/m³) O3 (µg/m³) Temperature (°C) Humidity (%)  \
# Civil Lines         31.3       18.7             22.1           73
# Rambagh             32.0       18.0             22.1           73
# Naini               34.0       17.0             22.1           73
# Phoolpur            36.0       16.0             22.1           73
# Katra               29.0       20.0             22.1           73
# ...

# %% [markdown]
# ## Resetting Index and Creating Location Column

# %%
df_final = df_final.reset_index()

df_final = df_final.rename(columns={"index": "Location"})

df_final.head()
# Out:
# Parameter     Location    AQI PM2.5 (µg/m³) PM10 (µg/m³) NO2 (µg/m³)  \
# 0          Civil Lines  228.3           125          245        34.7
# 1              Rambagh  235.0           130          255        36.0
# 2                Naini  250.0           140          270        39.0
# 3             Phoolpur  260.0           145          280        40.0
# 4                Katra  215.0           118          230        32.0
#
# Parameter SO2 (µg/m³) NH3 (µg/m³) O3 (µg/m³) Temperature (°C) Humidity (%)  \
# 0                 9.0        31.3       18.7             22.1           73
# 1                 9.0        32.0       18.0             22.1           73
# 2                10.0        34.0       17.0             22.1           73
# 3                11.0        36.0       16.0             22.1           73
# 4                 8.0        29.0       20.0             22.1           73
#
# Parameter Wind Speed (m/s)
# 0                      1.4
# 1                      1.4
# ...

# %%
df_final.columns
# Out:
# Index(['Location', 'AQI', 'PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO2 (µg/m³)',
#        'SO2 (µg/m³)', 'NH3 (µg/m³)', 'O3 (µg/m³)', 'Temperature (°C)',
#        'Humidity (%)', 'Wind Speed (m/s)'],
#       dtype='str', name='Parameter')

# %% [markdown]
# ## Checking Final Dataset Information

# %%
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          7 non-null      str
#  1   AQI               7 non-null      str
#  2   PM2.5 (µg/m³)     7 non-null      str
#  3   PM10 (µg/m³)      7 non-null      str
#  4   NO2 (µg/m³)       7 non-null      str
#  5   SO2 (µg/m³)       7 non-null      str
#  6   NH3 (µg/m³)       7 non-null      str
#  7   O3 (µg/m³)        7 non-null      str
#  8   Temperature (°C)  7 non-null      str
#  9   Humidity (%)      7 non-null      str
#  10  Wind Speed (m/s)  7 non-null      str
# dtypes: str(11)
# memory usage: 748.0 bytes

# %% [markdown]
# ## Converting Data Types

# %%
# Convert all columns except Location to numeric

numeric_columns = df_final.columns[1:]

df_final[numeric_columns] = df_final[numeric_columns].apply(pd.to_numeric)

print("Data types converted successfully ✅")
# Out:
# Data types converted successfully ✅

# %%
df_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          7 non-null      str
#  1   AQI               7 non-null      float64
#  2   PM2.5 (µg/m³)     7 non-null      int64
#  3   PM10 (µg/m³)      7 non-null      int64
#  4   NO2 (µg/m³)       7 non-null      float64
#  5   SO2 (µg/m³)       7 non-null      float64
#  6   NH3 (µg/m³)       7 non-null      float64
#  7   O3 (µg/m³)        7 non-null      float64
#  8   Temperature (°C)  7 non-null      float64
#  9   Humidity (%)      7 non-null      int64
#  10  Wind Speed (m/s)  7 non-null      float64
# dtypes: float64(7), int64(3), str(1)
# memory usage: 748.0 bytes

# %% [markdown]
# ## Previewing Second Extracted Table

# %%
df2 = pd.DataFrame(all_tables[1])

print("Shape:", df2.shape)

df2.head(10)
# Out:
# Shape: (14, 8)
#                                   0             1        2                3  \
# 0  JANUARY (2018) - DECEMBER (2018)           NaN      NaN              NaN
# 1                                                      NaN
# 2                  Air Quality Data  Traffic Area      NaN  Industrial Area
# 3                               NaN   Civil Lines  Rambagh            Naini
# 4                               AQI           225      235              255
# 5                     PM2.5 (µg/m³)           125      130              145
# 6                      PM10 (µg/m³)           240      250              280
# 7                       NO2 (µg/m³)            36       38               41
# 8                       SO2 (µg/m³)             9        9               10
# 9                       NH3 (µg/m³)            32       33               36
#
#           4                 5            6             7
# 0       NaN               NaN          NaN           NaN
# ...

# %% [markdown]
# ## Cleaning Second Extracted Table

# %%
df2 = df2.iloc[4:].reset_index(drop=True)

df2.columns = [
    "Parameter",
    "Civil Lines",
    "Rambagh",
    "Naini",
    "Phoolpur",
    "Katra",
    "Teliyarganj",
    "Company Bagh"
]

df2.head()
# Out:
#        Parameter Civil Lines Rambagh Naini Phoolpur Katra Teliyarganj  \
# 0            AQI         225     235   255      265   215         195
# 1  PM2.5 (µg/m³)         125     130   145      150   120         105
# 2   PM10 (µg/m³)         240     250   280      290   230         205
# 3    NO2 (µg/m³)          36      38    41       43    33          29
# 4    SO2 (µg/m³)           9       9    10       11     8           7
#
#   Company Bagh
# 0          130
# 1           65
# 2          135
# 3           17
# 4            5

# %%
df2 = df2.set_index("Parameter").T.reset_index()

df2.rename(columns={"index": "Location"}, inplace=True)

df2.head()
# Out:
# Parameter     Location  AQI PM2.5 (µg/m³) PM10 (µg/m³) NO2 (µg/m³)  \
# 0          Civil Lines  225           125          240          36
# 1              Rambagh  235           130          250          38
# 2                Naini  255           145          280          41
# 3             Phoolpur  265           150          290          43
# 4                Katra  215           120          230          33
#
# Parameter SO2 (µg/m³) NH3 (µg/m³) O3 (µg/m³) Temperature (°C) Humidity (%)  \
# 0                   9          32         19             25.3           72
# 1                   9          33         18             25.3           72
# 2                  10          36         17             25.2           71
# 3                  11          38         16             25.2           71
# 4                   8          30         21             25.3           73
#
# Parameter Wind Speed (m/s)
# 0                      1.5
# 1                      1.5
# ...

# %%
numeric_columns = df2.columns[1:]

df2[numeric_columns] = df2[numeric_columns].apply(pd.to_numeric)

df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          7 non-null      str
#  1   AQI               7 non-null      int64
#  2   PM2.5 (µg/m³)     7 non-null      int64
#  3   PM10 (µg/m³)      7 non-null      int64
#  4   NO2 (µg/m³)       7 non-null      int64
#  5   SO2 (µg/m³)       7 non-null      int64
#  6   NH3 (µg/m³)       7 non-null      int64
#  7   O3 (µg/m³)        7 non-null      int64
#  8   Temperature (°C)  7 non-null      float64
#  9   Humidity (%)      7 non-null      int64
#  10  Wind Speed (m/s)  7 non-null      float64
# dtypes: float64(2), int64(8), str(1)
# memory usage: 748.0 bytes

# %%
df2.describe()
# Out:
# Parameter         AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# count        7.000000        7.00000      7.000000     7.000000     7.000000
# mean       217.142857      120.00000    232.857143    33.857143     8.428571
# std         45.079295       28.57738     51.950068     8.802056     1.988060
# min        130.000000       65.00000    135.000000    17.000000     5.000000
# 25%        205.000000      112.50000    217.500000    31.000000     7.500000
# 50%        225.000000      125.00000    240.000000    36.000000     9.000000
# 75%        245.000000      137.50000    265.000000    39.500000     9.500000
# max        265.000000      150.00000    290.000000    43.000000    11.000000
#
# Parameter  NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  \
# count         7.000000    7.000000          7.000000      7.000000
# mean         30.142857   20.428571         25.185714     73.285714
# std           7.358183    4.466809          0.146385      3.147183
# ...

# %% [markdown]
# ## Cleaning Third Extracted Table

# %%
df3 = pd.DataFrame(all_tables[2])

print("Shape:", df3.shape)

df3.head(10)
# Out:
# Shape: (14, 8)
#                                   0             1        2                3  \
# 0  JANUARY (2021) - DECEMBER (2021)           NaN      NaN              NaN
# 1                                                      NaN
# 2                  Air Quality Data  Traffic Area      NaN  Industrial Area
# 3                               NaN   Civil Lines  Rambagh            Naini
# 4                               AQI           220      230              250
# 5                     PM2.5 (µg/m³)           125      130              145
# 6                      PM10 (µg/m³)           240      250              280
# 7                       NO2 (µg/m³)            36       38               41
# 8                       SO2 (µg/m³)             9        9               10
# 9                       NH3 (µg/m³)            32       33               36
#
#           4                 5            6             7
# 0       NaN               NaN          NaN           NaN
# ...

# %%
df3 = df3.iloc[4:].reset_index(drop=True)

df3.columns = [
    "Parameter",
    "Civil Lines",
    "Rambagh",
    "Naini",
    "Phoolpur",
    "Katra",
    "Teliyarganj",
    "Company Bagh"
]

df3.head()
# Out:
#        Parameter Civil Lines Rambagh Naini Phoolpur Katra Teliyarganj  \
# 0            AQI         220     230   250      260   210         190
# 1  PM2.5 (µg/m³)         125     130   145      150   120         105
# 2   PM10 (µg/m³)         240     250   280      290   230         205
# 3    NO2 (µg/m³)          36      38    41       43    34          29
# 4    SO2 (µg/m³)           9       9    10       11     8           7
#
#   Company Bagh
# 0          130
# 1           70
# 2          135
# 3           17
# 4            5

# %%
df3 = df3.set_index("Parameter").T.reset_index()

df3.rename(columns={"index": "Location"}, inplace=True)

df3.head()
# Out:
# Parameter     Location  AQI PM2.5 (µg/m³) PM10 (µg/m³) NO2 (µg/m³)  \
# 0          Civil Lines  220           125          240          36
# 1              Rambagh  230           130          250          38
# 2                Naini  250           145          280          41
# 3             Phoolpur  260           150          290          43
# 4                Katra  210           120          230          34
#
# Parameter SO2 (µg/m³) NH3 (µg/m³) O3 (µg/m³) Temperature (°C) Humidity (%)  \
# 0                   9          32         18             25.6           72
# 1                   9          33         17             25.6           72
# 2                  10          36         16             25.5           71
# 3                  11          38         15             25.5           71
# 4                   8          30         20             25.6           73
#
# Parameter Wind Speed (m/s)
# 0                      1.5
# 1                      1.5
# ...

# %%
numeric_columns = df3.columns[1:]

df3[numeric_columns] = df3[numeric_columns].apply(pd.to_numeric)

print("Data types converted successfully ✅")
# Out:
# Data types converted successfully ✅

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          7 non-null      str
#  1   AQI               7 non-null      int64
#  2   PM2.5 (µg/m³)     7 non-null      int64
#  3   PM10 (µg/m³)      7 non-null      int64
#  4   NO2 (µg/m³)       7 non-null      int64
#  5   SO2 (µg/m³)       7 non-null      int64
#  6   NH3 (µg/m³)       7 non-null      int64
#  7   O3 (µg/m³)        7 non-null      int64
#  8   Temperature (°C)  7 non-null      float64
#  9   Humidity (%)      7 non-null      int64
#  10  Wind Speed (m/s)  7 non-null      float64
# dtypes: float64(2), int64(8), str(1)
# memory usage: 748.0 bytes

# %%
df3.describe()
# Out:
# Parameter         AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# count        7.000000       7.000000      7.000000     7.000000     7.000000
# mean       212.857143     120.714286    232.857143    34.000000     8.428571
# std         43.479607      26.992062     51.950068     8.793937     1.988060
# min        130.000000      70.000000    135.000000    17.000000     5.000000
# 25%        200.000000     112.500000    217.500000    31.500000     7.500000
# 50%        220.000000     125.000000    240.000000    36.000000     9.000000
# 75%        240.000000     137.500000    265.000000    39.500000     9.500000
# max        260.000000     150.000000    290.000000    43.000000    11.000000
#
# Parameter  NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  \
# count         7.000000    7.000000          7.000000      7.000000
# mean         30.285714   19.428571         25.471429     73.285714
# std           7.040698    4.466809          0.179947      3.147183
# ...

# %% [markdown]
# ## Cleaning Fourth Extracted Table

# %%
df4 = pd.DataFrame(all_tables[3])

print("Shape:", df4.shape)

df4.head(10)
# Out:
# Shape: (14, 8)
#                                   0             1        2                3  \
# 0  JANUARY (2024) - DECEMBER (2024)           NaN      NaN              NaN
# 1                                                      NaN
# 2                  Air Quality Data  Traffic Area      NaN  Industrial Area
# 3                               NaN   Civil Lines  Rambagh            Naini
# 4                               AQI           235      245              265
# 5                     PM2.5 (µg/m³)           130      135              150
# 6                      PM10 (µg/m³)           250      260              290
# 7                       NO2 (µg/m³)            36       38               42
# 8                       SO2 (µg/m³)             9        9               10
# 9                       NH3 (µg/m³)            32       33               37
#
#           4                 5            6             7
# 0       NaN               NaN          NaN           NaN
# ...

# %%
df4 = df4.iloc[4:].reset_index(drop=True)

df4.columns = [
    "Parameter",
    "Civil Lines",
    "Rambagh",
    "Naini",
    "Phoolpur",
    "Katra",
    "Teliyarganj",
    "Company Bagh"
]

df4.head()
# Out:
#        Parameter Civil Lines Rambagh Naini Phoolpur Katra Teliyarganj  \
# 0            AQI         235     245   265      275   225         205
# 1  PM2.5 (µg/m³)         130     135   150      158   125         110
# 2   PM10 (µg/m³)         250     260   290      300   240         210
# 3    NO2 (µg/m³)          36      38    42       44    33          29
# 4    SO2 (µg/m³)           9       9    10       11     8           7
#
#   Company Bagh
# 0          140
# 1           70
# 2          140
# 3           18
# 4            5

# %%
df4 = df4.set_index("Parameter").T.reset_index()

df4.rename(columns={"index": "Location"}, inplace=True)

df4.head()
# Out:
# Parameter     Location  AQI PM2.5 (µg/m³) PM10 (µg/m³) NO2 (µg/m³)  \
# 0          Civil Lines  235           130          250          36
# 1              Rambagh  245           135          260          38
# 2                Naini  265           150          290          42
# 3             Phoolpur  275           158          300          44
# 4                Katra  225           125          240          33
#
# Parameter SO2 (µg/m³) NH3 (µg/m³) O3 (µg/m³) Temperature (°C) Humidity (%)  \
# 0                   9          32         18             26.2           71
# 1                   9          33         17             26.2           71
# 2                  10          37         16             26.1           70
# 3                  11          39         15             26.1           70
# 4                   8          31         20             26.2           72
#
# Parameter Wind Speed (m/s)
# 0                      1.5
# 1                      1.5
# ...

# %%
numeric_columns = df4.columns[1:]

df4[numeric_columns] = df4[numeric_columns].apply(pd.to_numeric)

print("Data types converted successfully ✅")

df4.info()
# Out:
# Data types converted successfully ✅
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          7 non-null      str
#  1   AQI               7 non-null      int64
#  2   PM2.5 (µg/m³)     7 non-null      int64
#  3   PM10 (µg/m³)      7 non-null      int64
#  4   NO2 (µg/m³)       7 non-null      int64
#  5   SO2 (µg/m³)       7 non-null      int64
#  6   NH3 (µg/m³)       7 non-null      int64
#  7   O3 (µg/m³)        7 non-null      int64
#  8   Temperature (°C)  7 non-null      float64
#  9   Humidity (%)      7 non-null      int64
#  10  Wind Speed (m/s)  7 non-null      float64
# dtypes: float64(2), int64(8), str(1)
# memory usage: 748.0 bytes

# %%
df4.describe()
# Out:
# Parameter         AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# count        7.000000       7.000000      7.000000     7.000000     7.000000
# mean       227.142857     125.428571    241.428571    34.285714     8.428571
# std         45.079295      29.119622     53.984125     8.807464     1.988060
# min        140.000000      70.000000    140.000000    18.000000     5.000000
# 25%        215.000000     117.500000    225.000000    31.000000     7.500000
# 50%        235.000000     130.000000    250.000000    36.000000     9.000000
# 75%        255.000000     142.500000    275.000000    40.000000     9.500000
# max        275.000000     158.000000    300.000000    44.000000    11.000000
#
# Parameter  NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  \
# count         7.000000    7.000000          7.000000      7.000000
# mean         31.000000   19.428571         26.071429     72.285714
# std           6.952218    4.466809          0.179947      3.147183
# ...

# %% [markdown]
# ## Merging All Cleaned AQI Tables

# %%
final_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

print("Merged successfully ✅")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 final_df = pd.concat([df1, df2, df3, df4], ignore_index=True)
#       2
#       3 print("Merged successfully ✅")
#
# NameError: name 'df1' is not defined

# %%
# %whos
# Out:
# Variable          Type         Data/Info
# ----------------------------------------
# all_tables        list         n=4
# df                DataFrame    Shape: (14, 8)
# df2               DataFrame    Shape: (7, 11)
# df3               DataFrame    Shape: (7, 11)
# df4               DataFrame    Shape: (7, 11)
# df_clean          DataFrame    Shape: (10, 8)
# df_final          DataFrame    Shape: (7, 11)
# np                module       <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>
# numeric_columns   Index        Index(['AQI', 'PM2.5 (µg/<...>='str', name='Parameter')
# os                module       <module 'os' (frozen)>
# page              Page         <Page:6>
# page_num          int          5
# pd                module       <module 'pandas' from 'c:<...>es\\pandas\\__init__.py'>
# pdf               PDF          <pdfplumber.pdf.PDF object at 0x000001D04230C980>
# pdf_path          str          data/prayagraj_air_quality_data (1).pdf
# ...

# %%
df1 = pd.DataFrame(all_tables[0])

# %%
df1 = df1.iloc[4:].reset_index(drop=True)

df1.columns = [
    "Parameter",
    "Civil Lines",
    "Rambagh",
    "Naini",
    "Phoolpur",
    "Katra",
    "Teliyarganj",
    "Company Bagh"
]

# %%
df1 = df1.set_index("Parameter").T.reset_index()

df1.rename(columns={"index": "Location"}, inplace=True)

# %%
numeric_columns = df1.columns[1:]

df1[numeric_columns] = df1[numeric_columns].apply(pd.to_numeric)

df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          7 non-null      str
#  1   AQI               7 non-null      float64
#  2   PM2.5 (µg/m³)     7 non-null      int64
#  3   PM10 (µg/m³)      7 non-null      int64
#  4   NO2 (µg/m³)       7 non-null      float64
#  5   SO2 (µg/m³)       7 non-null      float64
#  6   NH3 (µg/m³)       7 non-null      float64
#  7   O3 (µg/m³)        7 non-null      float64
#  8   Temperature (°C)  7 non-null      float64
#  9   Humidity (%)      7 non-null      int64
#  10  Wind Speed (m/s)  7 non-null      float64
# dtypes: float64(7), int64(3), str(1)
# memory usage: 748.0 bytes

# %%
print(df1.shape)
# Out:
# (7, 11)

# %%
final_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

print("Merged successfully ✅")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 final_df = pd.concat([df1, df2, df3, df4], ignore_index=True)
#       2
#       3 print("Merged successfully ✅")
#
# NameError: name 'df1' is not defined

# %%
type(final_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 type(final_df)
#
# NameError: name 'final_df' is not defined

# %%
# Features (Input)
X = final_df.drop(columns=["AQI", "Location"])

# Target (Output)
y = final_df["AQI"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Features (Input)
# ----> 2 X = final_df.drop(columns=["AQI", "Location"])
#       3
#       4 # Target (Output)
#       5 y = final_df["AQI"]
#
# NameError: name 'final_df' is not defined

# %%
print(X.shape)
print(y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(X.shape)
#       2 print(y.shape)
#
# NameError: name 'X' is not defined

# %%
print("Shape:", final_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 print("Shape:", final_df.shape)
#
# NameError: name 'final_df' is not defined

# %%
final_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 final_df.head(10)
#
# NameError: name 'final_df' is not defined

# %%
import pandas as pd

final_df = pd.read_csv("../data/cleaned_aqi_dataset.csv")

print(final_df.shape)
final_df.head()
# Out:
# (28, 11)
#       Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# 0  Civil Lines  228.3            125           245         34.7          9.0
# 1      Rambagh  235.0            130           255         36.0          9.0
# 2        Naini  250.0            140           270         39.0         10.0
# 3     Phoolpur  260.0            145           280         40.0         11.0
# 4        Katra  215.0            118           230         32.0          8.0
#
#    NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0         31.3        18.7              22.1            73               1.4
# 1         32.0        18.0              22.1            73               1.4
# 2         34.0        17.0              22.1            73               1.3
# 3         36.0        16.0              22.1            73               1.3
# 4         29.0        20.0              22.1            73               1.5

# %%
import pandas as pd

final_df = pd.read_csv("../data/cleaned_aqi_dataset.csv")

# %%
print(final_df.shape)
# Out:
# (28, 11)

# %%
final_df.head()
# Out:
#       Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# 0  Civil Lines  228.3            125           245         34.7          9.0
# 1      Rambagh  235.0            130           255         36.0          9.0
# 2        Naini  250.0            140           270         39.0         10.0
# 3     Phoolpur  260.0            145           280         40.0         11.0
# 4        Katra  215.0            118           230         32.0          8.0
#
#    NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0         31.3        18.7              22.1            73               1.4
# 1         32.0        18.0              22.1            73               1.4
# 2         34.0        17.0              22.1            73               1.3
# 3         36.0        16.0              22.1            73               1.3
# 4         29.0        20.0              22.1            73               1.5

# %% [markdown]
# ## Exporting Cleaned AQI Dataset

# %%
final_df.to_csv("../data/cleaned_aqi_dataset.csv", index=False)

print("Cleaned dataset exported successfully ✅")
# Out:
# Cleaned dataset exported successfully ✅

# %%
import os

print(os.path.exists("../data/cleaned_aqi_dataset.csv"))
# Out:
# True

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
final_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          28 non-null     str
#  1   AQI               28 non-null     float64
#  2   PM2.5 (µg/m³)     28 non-null     int64
#  3   PM10 (µg/m³)      28 non-null     int64
#  4   NO2 (µg/m³)       28 non-null     float64
#  5   SO2 (µg/m³)       28 non-null     float64
#  6   NH3 (µg/m³)       28 non-null     float64
#  7   O3 (µg/m³)        28 non-null     float64
#  8   Temperature (°C)  28 non-null     float64
#  9   Humidity (%)      28 non-null     int64
#  10  Wind Speed (m/s)  28 non-null     float64
# dtypes: float64(7), int64(3), str(1)
# memory usage: 2.5 KB

# %%
final_df.isnull().sum()
# Out:
# Parameter
# Location            0
# AQI                 0
# PM2.5 (µg/m³)       0
# PM10 (µg/m³)        0
# NO2 (µg/m³)         0
# SO2 (µg/m³)         0
# NH3 (µg/m³)         0
# O3 (µg/m³)          0
# Temperature (°C)    0
# Humidity (%)        0
# Wind Speed (m/s)    0
# dtype: int64

# %%
final_df.describe()
# Out:
# Parameter         AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# count       28.000000      28.000000     28.000000    28.000000    28.000000
# mean       217.796429     120.928571    234.285714    33.560714     8.428571
# std         43.068821      26.890627     49.809160     8.291197     1.874361
# min        120.000000      60.000000    125.000000    15.000000     5.000000
# 25%        202.500000     108.750000    208.750000    29.000000     7.000000
# 50%        226.650000     125.000000    242.500000    36.000000     9.000000
# 75%        250.000000     141.250000    272.500000    39.250000    10.000000
# max        275.000000     158.000000    300.000000    44.000000    11.000000
#
# Parameter  NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  \
# count        28.000000   28.000000         28.000000      28.00000
# mean         30.082143   19.810714         24.696429      73.25000
# std           6.745372    4.139631          1.592455       2.92657
# ...

# %% [markdown]
# ## AQI Distribution Analysis

# %%
plt.figure(figsize=(8,5))

plt.hist(final_df["AQI"], bins=8)

plt.title("Distribution of AQI")
plt.xlabel("AQI")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.boxplot(final_df["AQI"])

plt.title("AQI Boxplot")

plt.show()

# %%
plt.figure(figsize=(10,5))

final_df.groupby("Location")["AQI"].mean().plot(kind="bar")

plt.title("Average AQI by Location")
plt.xlabel("Location")
plt.ylabel("Average AQI")

plt.xticks(rotation=45)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))

sns.heatmap(
    final_df.select_dtypes(include=["number"]).corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Matrix")
plt.show()

# %%
plt.figure(figsize=(10,5))

for location in final_df["Location"].unique():
    temp = final_df[final_df["Location"] == location]
    plt.plot(temp.index, temp["AQI"], marker="o", label=location)

plt.title("AQI Trend by Location")
plt.xlabel("Observation")
plt.ylabel("AQI")
plt.legend()
plt.grid(True)

plt.show()

# %%
final_df.describe()
# Out:
# Parameter         AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# count       28.000000      28.000000     28.000000    28.000000    28.000000
# mean       217.796429     120.928571    234.285714    33.560714     8.428571
# std         43.068821      26.890627     49.809160     8.291197     1.874361
# min        120.000000      60.000000    125.000000    15.000000     5.000000
# 25%        202.500000     108.750000    208.750000    29.000000     7.000000
# 50%        226.650000     125.000000    242.500000    36.000000     9.000000
# 75%        250.000000     141.250000    272.500000    39.250000    10.000000
# max        275.000000     158.000000    300.000000    44.000000    11.000000
#
# Parameter  NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  \
# count        28.000000   28.000000         28.000000      28.00000
# mean         30.082143   19.810714         24.696429      73.25000
# std           6.745372    4.139631          1.592455       2.92657
# ...

# %% [markdown]
# # Machine Learning Model Preparation
#
# Preparing features and target variable for AQI prediction.

# %%
# Features (Input)
X = final_df.drop(columns=["AQI", "Location"])

# Target (Output)
y = final_df["AQI"]

# %%
print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (28, 9)
# Target Shape: (28,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("Training Data :", X_train.shape)
print("Testing Data  :", X_test.shape)
# Out:
# Training Data : (22, 9)
# Testing Data  : (6, 9)

# %% [markdown]
# # Random Forest Regression
#
# Training Random Forest model for AQI prediction.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 rf_model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
print(X_train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(X_train.shape)
#
# NameError: name 'X_train' is not defined

# %%
print(final_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(final_df.shape)
#
# NameError: name 'final_df' is not defined

# %%
import pandas as pd

# %%
import os

print(os.listdir("data"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import os
#       2
# ----> 3 print(os.listdir("data"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data'

# %%
import os

print(os.getcwd())
# Out:
# e:\OneDrive\Desktop\AQI_Prediction_System\notebooks

# %%
import os

print(os.listdir("../data"))
# Out:
# ['cleaned_aqi_dataset.csv', 'prayagraj_air_quality_data (1).pdf']

# %%
import pandas as pd

final_df = pd.read_csv("../data/cleaned_aqi_dataset.csv")

# %%
print(final_df.shape)
# Out:
# (28, 11)

# %%
final_df.head()
# Out:
#       Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# 0  Civil Lines  228.3            125           245         34.7          9.0
# 1      Rambagh  235.0            130           255         36.0          9.0
# 2        Naini  250.0            140           270         39.0         10.0
# 3     Phoolpur  260.0            145           280         40.0         11.0
# 4        Katra  215.0            118           230         32.0          8.0
#
#    NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0         31.3        18.7              22.1            73               1.4
# 1         32.0        18.0              22.1            73               1.4
# 2         34.0        17.0              22.1            73               1.3
# 3         36.0        16.0              22.1            73               1.3
# 4         29.0        20.0              22.1            73               1.5

# %%
X = final_df.drop(columns=["AQI", "Location"])
y = final_df["AQI"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (22, 9)
# (6, 9)

# %% [markdown]
# # Random Forest Regression
#
# Training the Random Forest Regressor model for AQI prediction.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
print("Random Forest Model Trained Successfully!")
# Out:
# Random Forest Model Trained Successfully!

# %% [markdown]
# # Random Forest Prediction
#
# Making predictions on the test dataset.

# %%
rf_predictions = rf_model.predict(X_test)

# %%
print(rf_predictions)
# Out:
# [252.3  217.4  230.55 229.9  222.75 192.2 ]

# %%
comparison_df = pd.DataFrame({
    "Actual AQI": y_test.values,
    "Predicted AQI": rf_predictions
})

comparison_df
# Out:
#    Actual AQI  Predicted AQI
# 0       255.0         252.30
# 1       225.0         217.40
# 2       235.0         230.55
# 3       235.0         229.90
# 4       228.3         222.75
# 5       195.0         192.20

# %% [markdown]
# # Random Forest Model Evaluation
#
# Evaluating the Random Forest model using regression metrics.

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
mae = mean_absolute_error(y_test, rf_predictions)

mse = mean_squared_error(y_test, rf_predictions)

rmse = mse ** 0.5

r2 = r2_score(y_test, rf_predictions)

# %%
print(f"MAE : {mae:.2f}")

print(f"RMSE : {rmse:.2f}")

print(f"R² Score : {r2:.4f}")
# Out:
# MAE : 4.70
# RMSE : 4.99
# R² Score : 0.9221

# %%
import xgboost

print(xgboost.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import xgboost
#       2
#       3 print(xgboost.__version__)
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
print(final_df.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (28, 11)
# (22, 9)
# (6, 9)

# %%
print(final_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(final_df.shape)
#
# NameError: name 'final_df' is not defined

# %%
import pandas as pd

# %%
final_df = pd.read_csv("../data/cleaned_aqi_dataset.csv")

print(final_df.shape)
# Out:
# (28, 11)

# %%
# Features (Input)
X = final_df.drop(columns=["AQI", "Location"])

# Target (Output)
y = final_df["AQI"]

print(X.shape)
print(y.shape)
# Out:
# (28, 9)
# (28,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (22, 9)
# (6, 9)

# %% [markdown]
# # XGBoost Regression
#
# Training the XGBoost Regressor model for AQI prediction.

# %%
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from xgboost import XGBRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\python.exe

# %%
from xgboost import XGBRegressor

print("XGBoost imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from xgboost import XGBRegressor
#       2
#       3 print("XGBoost imported successfully!")
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import pandas as pd

final_df = pd.read_csv("../data/cleaned_aqi_dataset.csv")

print(final_df.shape)
# Out:
# (28, 11)

# %%
X = final_df.drop(columns=["Location", "AQI"])
y = final_df["AQI"]

print(X.shape)
# Out:
# (28, 9)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (22, 9)
# (6, 9)

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\python.exe

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\python.exe

# %%
import subprocess
import sys

subprocess.run([sys.executable, "-m", "pip", "show", "xgboost"])
# Out:
# CompletedProcess(args=['c:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python313\\python.exe', '-m', 'pip', 'show', 'xgboost'], returncode=0)

# %%
import importlib.util

print(importlib.util.find_spec("xgboost"))
# Out:
# ModuleSpec(name='xgboost', loader=<_frozen_importlib_external.SourceFileLoader object at 0x000001A4DC27F290>, origin='c:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\xgboost\\__init__.py', submodule_search_locations=['c:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\xgboost'])

# %%
import site

print(site.getsitepackages())
# Out:
# ['c:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python313', 'c:\\Users\\DELL\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages']

# %%
import xgboost

print("Version:", xgboost.__version__)
# Out:
# Version: 3.3.0

# %%
from xgboost import XGBRegressor

print("XGBRegressor imported successfully! 🚀")
# Out:
# XGBRegressor imported successfully! 🚀

# %% [markdown]
# # XGBoost Regression Model
#
# Training XGBoost Regressor for AQI Prediction.

# %%
xgb_model = XGBRegressor(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    random_state=42
)

# %%
xgb_model.fit(X_train, y_train)

print("XGBoost Model Trained Successfully! 🎉")
# Out:
# XGBoost Model Trained Successfully! 🎉

# %%
xgb_predictions = xgb_model.predict(X_test)

# %%
comparison_xgb = pd.DataFrame({
    "Actual AQI": y_test.values,
    "Predicted AQI": xgb_predictions
})

comparison_xgb
# Out:
#    Actual AQI  Predicted AQI
# 0       255.0     254.017715
# 1       225.0     220.841934
# 2       235.0     230.476074
# 3       235.0     230.476639
# 4       228.3     222.092712
# 5       195.0     190.017426

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

xgb_mae = mean_absolute_error(y_test, xgb_predictions)

xgb_mse = mean_squared_error(y_test, xgb_predictions)

xgb_rmse = xgb_mse ** 0.5

xgb_r2 = r2_score(y_test, xgb_predictions)

print(f"MAE : {xgb_mae:.2f}")
print(f"RMSE : {xgb_rmse:.2f}")
print(f"R² Score : {xgb_r2:.4f}")
# Out:
# MAE : 4.23
# RMSE : 4.52
# R² Score : 0.9362

# %% [markdown]
# # Model Comparison
#
# Comparing the performance of Random Forest and XGBoost Regression models.

# %%
comparison = pd.DataFrame({
    "Model": ["Random Forest", "XGBoost"],
    "MAE": [rf_mae, xgb_mae],
    "RMSE": [rf_rmse, xgb_rmse],
    "R² Score": [rf_r2, xgb_r2]
})

comparison
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 comparison = pd.DataFrame({
#       2     "Model": ["Random Forest", "XGBoost"],
# ----> 3     "MAE": [rf_mae, xgb_mae],
#       4     "RMSE": [rf_rmse, xgb_rmse],
#       5     "R² Score": [rf_r2, xgb_r2]
#       6 })
#
# NameError: name 'rf_mae' is not defined

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# %%
rf_model.fit(X_train, y_train)

print("Random Forest Model Trained Successfully!")
# Out:
# Random Forest Model Trained Successfully!

# %%
rf_predictions = rf_model.predict(X_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

rf_mae = mean_absolute_error(y_test, rf_predictions)

rf_mse = mean_squared_error(y_test, rf_predictions)

rf_rmse = rf_mse ** 0.5

rf_r2 = r2_score(y_test, rf_predictions)

print(f"MAE : {rf_mae:.2f}")
print(f"RMSE : {rf_rmse:.2f}")
print(f"R² Score : {rf_r2:.4f}")
# Out:
# MAE : 4.70
# RMSE : 4.99
# R² Score : 0.9221

# %%
comparison = pd.DataFrame({
    "Model": ["Random Forest", "XGBoost"],
    "MAE": [rf_mae, xgb_mae],
    "RMSE": [rf_rmse, xgb_rmse],
    "R² Score": [rf_r2, xgb_r2]
})

comparison
# Out:
#            Model       MAE      RMSE  R² Score
# 0  Random Forest  4.700000  4.991743  0.922149
# 1        XGBoost  4.229583  4.519173  0.936192

# %% [markdown]
# # Saving the Best Model
#
# Saving the trained XGBoost model for future predictions.

# %%
import joblib

# %%
joblib.dump(
    xgb_model,
    "../models/xgboost_aqi_model.pkl"
)

print("Model Saved Successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 joblib.dump(
#       2     xgb_model,
#       3     "../models/xgboost_aqi_model.pkl"
#       4 )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\joblib\numpy_pickle.py:599, in dump(value, filename, compress, protocol)
#     597         NumpyPickler(f, protocol=protocol).dump(value)
#     598 elif is_filename:
# --> 599     with open(filename, "wb") as f:
#     600         NumpyPickler(f, protocol=protocol).dump(value)
#     601 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../models/xgboost_aqi_model.pkl'

# %%
import joblib

joblib.dump(
    xgb_model,
    "../models/xgboost_aqi_model.pkl"
)

print("✅ XGBoost Model Saved Successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import joblib
#       2
#       3 joblib.dump(
# ----> 4     xgb_model,
#       5     "../models/xgboost_aqi_model.pkl"
#       6 )
#       7
#
# NameError: name 'xgb_model' is not defined

# %%
import os

print(os.path.exists("../models/xgboost_aqi_model.pkl"))
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_AQI_dataset.csv")

print(df.columns.tolist())
# Out:
# ['Location', 'AQI', 'PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO2 (µg/m³)', 'SO2 (µg/m³)', 'NH3 (µg/m³)', 'O3 (µg/m³)', 'Temperature (°C)', 'Humidity (%)', 'Wind Speed (m/s)']

# %%
df.shape
# Out:
# (28, 11)

# %%
df.head()
# Out:
#       Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# 0  Civil Lines  228.3            125           245         34.7          9.0
# 1      Rambagh  235.0            130           255         36.0          9.0
# 2        Naini  250.0            140           270         39.0         10.0
# 3     Phoolpur  260.0            145           280         40.0         11.0
# 4        Katra  215.0            118           230         32.0          8.0
#
#    NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0         31.3        18.7              22.1            73               1.4
# 1         32.0        18.0              22.1            73               1.4
# 2         34.0        17.0              22.1            73               1.3
# 3         36.0        16.0              22.1            73               1.3
# 4         29.0        20.0              22.1            73               1.5

# %%
df["Location"].unique()
# Out:
# <ArrowStringArray>
# [ 'Civil Lines',      'Rambagh',        'Naini',     'Phoolpur',
#         'Katra',  'Teliyarganj', 'Company Bagh']
# Length: 7, dtype: str

# %%
import pickle

model = pickle.load(open("models/XGBoost_AQI_Model.pkl","rb"))

print(model.feature_names_in_)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pickle
#       2
# ----> 3 model = pickle.load(open("models/XGBoost_AQI_Model.pkl","rb"))
#       4
#       5 print(model.feature_names_in_)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/XGBoost_AQI_Model.pkl'

# %%
import os

os.getcwd()
# Out:
# 'e:\\OneDrive\\Desktop\\AQI_Prediction_System\\notebooks'

# %%
os.listdir()
# Out:
# ['01_Data_Preprocessing.ipynb']

# %%
os.listdir("models")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 os.listdir("models")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'models'

# %%
import pickle

model = pickle.load(
    open("models/xgboost_aqi_model.pkl", "rb")
)

print(model.feature_names_in_)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 4
#       1 import pickle
#       2
#       3 model = pickle.load(
# ----> 4     open("models/xgboost_aqi_model.pkl", "rb")
#       5 )
#       6
#       7 print(model.feature_names_in_)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/xgboost_aqi_model.pkl'

# %%
import os

os.listdir("models")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 import os
#       2
# ----> 3 os.listdir("models")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'models'

# %%
print(df.columns.tolist())
# Out:
# ['Location', 'AQI', 'PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO2 (µg/m³)', 'SO2 (µg/m³)', 'NH3 (µg/m³)', 'O3 (µg/m³)', 'Temperature (°C)', 'Humidity (%)', 'Wind Speed (m/s)']

# %%
X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 X.columns
#
# NameError: name 'X' is not defined

# %%
print(X.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(X.columns.tolist())
#
# NameError: name 'X' is not defined

# %%
df.head()
# Out:
#       Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# 0  Civil Lines  228.3            125           245         34.7          9.0
# 1      Rambagh  235.0            130           255         36.0          9.0
# 2        Naini  250.0            140           270         39.0         10.0
# 3     Phoolpur  260.0            145           280         40.0         11.0
# 4        Katra  215.0            118           230         32.0          8.0
#
#    NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0         31.3        18.7              22.1            73               1.4
# 1         32.0        18.0              22.1            73               1.4
# 2         34.0        17.0              22.1            73               1.3
# 3         36.0        16.0              22.1            73               1.3
# 4         29.0        20.0              22.1            73               1.5

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Location          28 non-null     str
#  1   AQI               28 non-null     float64
#  2   PM2.5 (µg/m³)     28 non-null     int64
#  3   PM10 (µg/m³)      28 non-null     int64
#  4   NO2 (µg/m³)       28 non-null     float64
#  5   SO2 (µg/m³)       28 non-null     float64
#  6   NH3 (µg/m³)       28 non-null     float64
#  7   O3 (µg/m³)        28 non-null     float64
#  8   Temperature (°C)  28 non-null     float64
#  9   Humidity (%)      28 non-null     int64
#  10  Wind Speed (m/s)  28 non-null     float64
# dtypes: float64(7), int64(3), str(1)
# memory usage: 2.8 KB

# %%
print(X.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(X.columns.tolist())
#
# NameError: name 'X' is not defined

# %%
import pandas as pd

df = pd.read_csv("../data/cleaned_AQI_dataset.csv")

df.head()
# Out:
#       Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  \
# 0  Civil Lines  228.3            125           245         34.7          9.0
# 1      Rambagh  235.0            130           255         36.0          9.0
# 2        Naini  250.0            140           270         39.0         10.0
# 3     Phoolpur  260.0            145           280         40.0         11.0
# 4        Katra  215.0            118           230         32.0          8.0
#
#    NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0         31.3        18.7              22.1            73               1.4
# 1         32.0        18.0              22.1            73               1.4
# 2         34.0        17.0              22.1            73               1.3
# 3         36.0        16.0              22.1            73               1.3
# 4         29.0        20.0              22.1            73               1.5

# %%
import pandas as pd

df = pd.read_csv("data/cleaned_AQI_dataset.csv")

df.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("data/cleaned_AQI_dataset.csv")
#       4
#       5 df.columns.tolist()
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# e:\OneDrive\Desktop\AQI_Prediction_System\notebooks

# %%
import os

print("Files/Folders here:")
print(os.listdir())
# Out:
# Files/Folders here:
# ['01_Data_Preprocessing.ipynb', 'models']

# %%
import os

print(os.path.exists("models"))
print(os.path.exists("../models"))
# Out:
# True
# False

# %%
import os

print(os.path.exists("../models/xgboost_aqi_model.pkl"))

# %%
print("Hello Anjali")
# Out:
# Hello Anjali

# %%
import joblib

joblib.dump(
    xgb_model,
    "models/xgboost_aqi_model.pkl"
)

print("✅ XGBoost Model Saved Successfully!")
# Out:
# ✅ XGBoost Model Saved Successfully!

# %%
import os

print(os.listdir("models"))
# Out:
# ['xgboost_aqi_model.pkl']

# %%
X.head()
# Out:
# Parameter  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  SO2 (µg/m³)  NH3 (µg/m³)  \
# 0                    125           245         34.7          9.0         31.3
# 1                    130           255         36.0          9.0         32.0
# 2                    140           270         39.0         10.0         34.0
# 3                    145           280         40.0         11.0         36.0
# 4                    118           230         32.0          8.0         29.0
#
# Parameter  O3 (µg/m³)  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0                18.7              22.1            73               1.4
# 1                18.0              22.1            73               1.4
# 2                17.0              22.1            73               1.3
# 3                16.0              22.1            73               1.3
# 4                20.0              22.1            73               1.5

# %%
y.head()
# Out:
# 0    228.3
# 1    235.0
# 2    250.0
# 3    260.0
# 4    215.0
# Name: AQI, dtype: float64

# %% [markdown]
# # Train-Test Split
#
# Splitting the dataset into training and testing sets.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 from sklearn.model_selection import train_test_split
#       2
#       3 X_train, X_test, y_train, y_test = train_test_split(
# ----> 4     X,
#       5     y,
#       6     test_size=0.20,
#       7     random_state=42
#
# NameError: name 'X' is not defined

# %%
# Features (Input)
X = final_df.drop(columns=["AQI", "Location"])

# Target (Output)
y = final_df["AQI"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Features (Input)
# ----> 2 X = final_df.drop(columns=["AQI", "Location"])
#       3
#       4 # Target (Output)
#       5 y = final_df["AQI"]
#
# NameError: name 'final_df' is not defined

# %%
print(final_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(final_df.shape)
#
# NameError: name 'final_df' is not defined

# %%
# %whos
# Out:
# Variable     Type      Data/Info
# --------------------------------
# np           module    <module 'numpy' from 'c:\<...>ges\\numpy\\__init__.py'>
# pd           module    <module 'pandas' from 'c:<...>es\\pandas\\__init__.py'>
# pdf_path     str       data/prayagraj_air_quality_data (1).pdf
# pdfplumber   module    <module 'pdfplumber' from<...>pdfplumber\\__init__.py'>
# plt          module    <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# sns          module    <module 'seaborn' from 'c<...>s\\seaborn\\__init__.py'>

# %%
print(final_df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(final_df.shape)
#
# NameError: name 'final_df' is not defined

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\python.exe
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.9.0

# %%
final_df.tail(10)
# Out:
# Parameter      Location    AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  NO2 (µg/m³)  \
# 18                Katra  210.0            120           230         34.0
# 19          Teliyarganj  190.0            105           205         29.0
# 20         Company Bagh  130.0             70           135         17.0
# 21          Civil Lines  235.0            130           250         36.0
# 22              Rambagh  245.0            135           260         38.0
# 23                Naini  265.0            150           290         42.0
# 24             Phoolpur  275.0            158           300         44.0
# 25                Katra  225.0            125           240         33.0
# 26          Teliyarganj  205.0            110           210         29.0
# 27         Company Bagh  140.0             70           140         18.0
#
# Parameter  SO2 (µg/m³)  NH3 (µg/m³)  O3 (µg/m³)  Temperature (°C)  \
# 18                 8.0         30.0        20.0              25.6
# ...

# %% [markdown]
# ## Import Required Libraries

# %%
# !python -m pip install matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 5.1 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.3 MB 5.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.3 MB 6.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.3 MB 6.6 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.3 MB 6.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.3 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------- -- 8.7/9.3 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 5.7 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------------- ---------------------- 1.0/2.3 MB 5.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 4.9 MB/s  0:00:00
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\python.exe

# %%
# !python -m pip install pandas
# Out:
# ...
#   Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.5.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.5-cp313-cp313-win_amd64.whl (9.8 MB)
# Using cached numpy-2.5.1-cp313-cp313-win_amd64.whl (12.4 MB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...
